# %%
# examples/basic_usage.py
from xml_reader import ReadXML
import importlib
import root_anatomy
import visualization
importlib.reload(root_anatomy)
importlib.reload(visualization)
from root_anatomy import RootAnatomy
from visualization import AnatomyMapper
import matplotlib.pyplot as plt

# %%
# 1. Load parameters
params = ReadXML("./data/root_monocot.xml")

# %%
root = RootAnatomy(params).generate()
print(root)
# Out:
# <RootAnatomy: 1482 cells, 4413 walls. Cell types: {'stele': 510, 'outer_cortex': 283, 'epidermis': 266, 'cortex': 140, 'inner_cortex': 94, 'exodermis': 87, 'pericycle': 60, 'endodermis': 42}>

# %%
mapper = AnatomyMapper(root)
mapper.plot()
# Out:
# (<Figure size 1000x1000 with 1 Axes>,
#  <Axes: title={'center': 'Root Anatomy Visualization (1467 cells)'}>)
